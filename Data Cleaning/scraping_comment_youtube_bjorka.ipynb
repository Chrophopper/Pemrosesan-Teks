# %% [markdown]
# ### Import Library

# %%
import pandas as pd
from googleapiclient.discovery import build

# %% [markdown]
# ## Mengambil id video
#
# menentukan ID video YouTube yang akan diambil komentarnya.

# %%
video_url = "https://youtu.be/LjNGYXuLA1I" # Replace with the actual video URL
# Extract video ID from the URL
video_id = video_url.split('/')[-1]
video_id
# Out:
# 'LjNGYXuLA1I'

# %% [markdown]
# ## Mengambil komentar
#
#
#  YouTube Data API v3 untuk mengambil komentar dari video yang ditentukan.

# %%
API_KEY = "AIzaSyD_NzKH6rwXq9N297sqAN4aTp8GwW7Di2s" # API_KEY Youtube V3

youtube = build('youtube', 'v3', developerKey=API_KEY)

comments = []
next_page_token = None
max_comments = 4000
results_per_request = 100

while len(comments) < max_comments:
    request = youtube.commentThreads().list(
        part='snippet',
        videoId=video_id,
        pageToken=next_page_token,
        maxResults=results_per_request
    )
    response = request.execute()

    for item in response['items']:
        comments.append(item['snippet']['topLevelComment']['snippet'])

    next_page_token = response.get('nextPageToken')

    if not next_page_token:
        break

print(f"Collected {len(comments)} comments.")
# Out:
# Collected 4000 comments.

# %% [markdown]
# ## Menyimpan data
#
# ### Subtask:
# Komentar yang diambil akan disimpan dalam format yang mudah dianalisis, seperti DataFrame pandas.

# %%
df_comments = pd.DataFrame(comments)
display(df_comments.head(100)) #menampilkan 100 data
print(f"Shape of the DataFrame: {df_comments.shape}")
# Out:
#                    channelId      videoId  \
# 0   UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1   UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 2   UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 3   UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 4   UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# ..                       ...          ...
# 95  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 96  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 97  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 98  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 99  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
#
#                                           textDisplay  \
# 0           We do not own what we produce—it owns us.
# 1   Ajibb . “KARNA GAK ADA PRESTASI MUNGKIN MEREKA...
# 2          Tugasnya hanya berdiri di depan SPBU foto2
# 3                       Malu maluin kepolisan konaha😂
# 4   Segitu parah nya instansi itu di mata rakyak, ...
# ..                                                ...
# 95  Polisi pengen  dianggap keren bs nangkep bjork...
# ...

# %% [markdown]
# ### Case Folding

# %%
import re

def clean_text(text):
    # Menghapus HTML tags
    text = re.sub(r'<.*?>', '', text)
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove special characters and symbols (keeping basic punctuation)
    text = re.sub(r'[^\w\s.,!?;:]', '', text)
    # Convert to lowercase (Case Folding)
    text = text.lower()

    text = text.strip()
    return text


df_comments['textOriginal'] = df_comments['textOriginal'].apply(clean_text)

display(df_comments.head())
# Out:
#                   channelId      videoId  \
# 0  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 2  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 3  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 4  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
#
#                                          textDisplay  \
# 0          We do not own what we produce—it owns us.
# 1  Ajibb . “KARNA GAK ADA PRESTASI MUNGKIN MEREKA...
# 2         Tugasnya hanya berdiri di depan SPBU foto2
# 3                      Malu maluin kepolisan konaha😂
# 4  Segitu parah nya instansi itu di mata rakyak, ...
#
#                                         textOriginal     authorDisplayName  \
# 0           we do not own what we produceit owns us.            @wenkhairu
# 1  ajibb . karna gak ada prestasi mungkin mereka ...  @mix_photocinema2693
# 2         tugasnya hanya berdiri di depan spbu foto2      @Lianifitria-d3x
# 3                       malu maluin kepolisan konaha             @Akuaryes
# ...

# %%
df_comments = pd.DataFrame(comments)
display(df_comments.head())
print(f"Shape of the DataFrame: {df_comments.shape}")
# Out:
#                   channelId      videoId  \
# 0  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 2  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 3  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 4  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
#
#                                          textDisplay  \
# 0          We do not own what we produce—it owns us.
# 1  Ajibb . “KARNA GAK ADA PRESTASI MUNGKIN MEREKA...
# 2         Tugasnya hanya berdiri di depan SPBU foto2
# 3                      Malu maluin kepolisan konaha😂
# 4  Segitu parah nya instansi itu di mata rakyak, ...
#
#                                         textOriginal     authorDisplayName  \
# 0          We do not own what we produce—it owns us.            @wenkhairu
# 1  Ajibb . “KARNA GAK ADA PRESTASI MUNGKIN MEREKA...  @mix_photocinema2693
# 2         Tugasnya hanya berdiri di depan SPBU foto2      @Lianifitria-d3x
# 3                      Malu maluin kepolisan konaha😂             @Akuaryes
# ...

# %% [markdown]
# ## Memeriksa data
#
# ### Subtask:
# Melihat informasi umum tentang DataFrame, seperti tipe data, jumlah nilai non-null, dan beberapa baris data untuk memahami kondisinya.

# %%
df_comments.info()
display(df_comments.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   channelId              4000 non-null   object
#  1   videoId                4000 non-null   object
#  2   textDisplay            4000 non-null   object
#  3   textOriginal           4000 non-null   object
#  4   authorDisplayName      4000 non-null   object
#  5   authorProfileImageUrl  4000 non-null   object
#  6   authorChannelUrl       4000 non-null   object
#  7   authorChannelId        4000 non-null   object
#  8   canRate                4000 non-null   bool
#  9   viewerRating           4000 non-null   object
#  10  likeCount              4000 non-null   int64
#  11  publishedAt            4000 non-null   object
#  12  updatedAt              4000 non-null   object
# dtypes: bool(1), int64(1), object(11)
# memory usage: 379.0+ KB
# ...

# %% [markdown]
# ## Menangani nilai yang hilang
#
# ### Subtask:
# Mengidentifikasi dan menangani nilai-nilai yang hilang (missing values) dalam DataFrame.

# %%
missing_values_count = df_comments.isnull().sum()
print("Missing values count per column:")
print(missing_values_count)
# Out:
# Missing values count per column:
# channelId                0
# videoId                  0
# textDisplay              0
# textOriginal             0
# authorDisplayName        0
# authorProfileImageUrl    0
# authorChannelUrl         0
# authorChannelId          0
# canRate                  0
# viewerRating             0
# likeCount                0
# publishedAt              0
# updatedAt                0
# dtype: int64

# %% [markdown]
# ## Membersihkan teks komentar
#
# ### Subtask:
# Membersihkan kolom teks komentar dari karakter yang tidak diinginkan, seperti tag HTML, URL, atau karakter khusus lainnya.

# %%
import re

def clean_text(text):
    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove special characters and symbols (keeping basic punctuation)
    text = re.sub(r'[^\w\s.,!?;:]', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove leading and trailing spaces
    text = text.strip()
    return text

df_comments['textOriginal'] = df_comments['textOriginal'].apply(clean_text)

display(df_comments.head())
# Out:
#                   channelId      videoId  \
# 0  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 2  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 3  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 4  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
#
#                                          textDisplay  \
# 0          We do not own what we produce—it owns us.
# 1  Ajibb . “KARNA GAK ADA PRESTASI MUNGKIN MEREKA...
# 2         Tugasnya hanya berdiri di depan SPBU foto2
# 3                      Malu maluin kepolisan konaha😂
# 4  Segitu parah nya instansi itu di mata rakyak, ...
#
#                                         textOriginal     authorDisplayName  \
# 0           we do not own what we produceit owns us.            @wenkhairu
# 1  ajibb . karna gak ada prestasi mungkin mereka ...  @mix_photocinema2693
# 2         tugasnya hanya berdiri di depan spbu foto2      @Lianifitria-d3x
# 3                       malu maluin kepolisan konaha             @Akuaryes
# ...

# %% [markdown]
# ## Menghapus duplikat
#
# ### Subtask:
# Mengidentifikasi dan menghapus komentar yang merupakan duplikat.

# %% [markdown]
# **Reasoning**:
# Identify and remove duplicate rows in the DataFrame, then display the head and shape of the resulting DataFrame to verify the changes.

# %%
df_comments.drop_duplicates(inplace=True)
display(df_comments.head())
print(f"Shape of the DataFrame after removing duplicates: {df_comments.shape}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3953617293.py in <cell line: 0>()
# ----> 1 df_comments.drop_duplicates(inplace=True)
#       2 display(df_comments.head())
#       3 print(f"Shape of the DataFrame after removing duplicates: {df_comments.shape}")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6956         else:
#    6957             vals = (col.values for name, col in self.items() if name in subset)
# ...

# %% [markdown]
# ## Menyimpan data
#
# ### Subtask:
# Komentar yang diambil akan disimpan dalam format yang mudah dianalisis, seperti DataFrame pandas.

# %%
df_comments.drop_duplicates(inplace=True)
display(df_comments.head())
print(f"Shape of the DataFrame after removing duplicates: {df_comments.shape}")
