# %% [markdown]
# ### Import Library

# %%
import pandas as pd
from googleapiclient.discovery import build

# %% [markdown]
# ## Mengambil id video
#
# menentukan ID video YouTube yang akan diambil komentarnya.

# %%
video_url = "https://youtu.be/LjNGYXuLA1I" # Replace with the actual video URL
# menampilkan Inti tautan
video_id = video_url.split('/')[-1]
video_id
# Out:
# 'LjNGYXuLA1I'

# %% [markdown]
# ## Mengambil komentar
#
#
#  YouTube Data API v3 untuk mengambil komentar dari video yang ditentukan.

# %%
API_KEY = "AIzaSyD_NzKH6rwXq9N297sqAN4aTp8GwW7Di2s" # API_KEY Youtube V3

youtube = build('youtube', 'v3', developerKey=API_KEY)

comments = []
next_page_token = None
max_comments = 2000
results_per_request = 100

while len(comments) < max_comments:
    request = youtube.commentThreads().list(
        part='snippet',
        videoId=video_id,
        pageToken=next_page_token,
        maxResults=results_per_request
    )
    response = request.execute()

    for item in response['items']:
        comments.append(item['snippet']['topLevelComment']['snippet'])

    next_page_token = response.get('nextPageToken')

    if not next_page_token:
        break

print(f"Collected {len(comments)} comments.")
# Out:
# Collected 2000 comments.

# %% [markdown]
# ## Menyimpan data
#
# Komentar yang diambil akan disimpan dalam variabel baru

# %%
df_comments = pd.DataFrame(comments)
df_comments #menampilkan 2000 data
# Out:
#                      channelId      videoId  \
# 0     UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1     UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 2     UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 3     UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 4     UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# ...                        ...          ...
# 1995  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1996  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1997  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1998  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1999  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
#
#                                             textDisplay  \
# 0     Nangkep bjorka???😂😂,🤭,<br>Ngakak guling guling...
# 1     mas nya ini masa juga g bisa mendeteksi bjorka...
# 2     kek udah tenang tenang gtu kan, gak viral si b...
# 3     Kalo ngobrol shootnya dua2nya akan lebih dinik...
# 4                                  Passwd : Admin1234 💅
# ...                                                 ...
# ...

# %% [markdown]
# ### Case Folding
#
# Melakukan Case Folding untuk merubah kata-kata yang sama tetapi memiliki format huruf yang berbeda dengan cara mengubah menjadi huruf kecil (lowecase).
#
# **Catatan :** Data yang telah dirubah pada parameter adalah textOriginal.

# %%
import re

def clean_text(text):
    # Menghapus HTML tags
    text = re.sub(r'<.*?>', '', text)
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Menghapus Tanda Baca yang tidak dibutuhkan
    text = re.sub(r'[^\w\s.,!?;:]', '', text)
    # Konversi menjadi Case Folding
    text = text.lower()

    text = text.strip()
    return text


df_comments['textOriginal'] = df_comments['textOriginal'].apply(clean_text)

display(df_comments.head())
# Out:
#                   channelId      videoId  \
# 0  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 1  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 2  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 3  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
# 4  UCYk4LJI0Pr6RBDWowMm-KUw  LjNGYXuLA1I
#
#                                          textDisplay  \
# 0  Nangkep bjorka???😂😂,🤭,<br>Ngakak guling guling...
# 1  mas nya ini masa juga g bisa mendeteksi bjorka...
# 2  kek udah tenang tenang gtu kan, gak viral si b...
# 3  Kalo ngobrol shootnya dua2nya akan lebih dinik...
# 4                               Passwd : Admin1234 💅
#
#                                         textOriginal      authorDisplayName  \
# 0  nangkep bjorka???,,\nngakak guling guling\nkal...              @MP-wf4ei
# 1  mas nya ini masa juga g bisa mendeteksi bjorka...         @nuriasmoro682
# 2  kek udah tenang tenang gtu kan, gak viral si b...  @m.irfanpamungkas8044
# 3  kalo ngobrol shootnya dua2nya akan lebih dinik...          @widyanto7506
# ...

# %%
df_comments.to_excel('processed_comments.xlsx', index=False)
